# %% [markdown]
# #### IMPORT REQUIRED LIBRARIES

# %%
import pandas as pd
from sklearn import tree
import graphviz
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score

# %% [markdown]
# #### IMPORT DATASET

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#      Sepal_length(cm)  Sepal_width(cm)  Petal_length(cm)  Petal_width(cm)  \
# 0                 5.1              3.5               1.4              0.2
# 1                 4.9              3.0               1.4              0.2
# 2                 4.7              3.2               1.3              0.2
# 3                 4.6              3.1               1.5              0.2
# 4                 5.0              3.6               1.4              0.2
# ..                ...              ...               ...              ...
# 145               6.7              3.0               5.2              2.3
# 146               6.3              2.5               5.0              1.9
# 147               6.5              3.0               5.2              2.0
# 148               6.2              3.4               5.4              2.3
# 149               5.9              3.0               5.1              1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# ...

# %% [markdown]
# #### BUILDING MODEL

# %%
x = df[['Sepal_length(cm)', 'Sepal_width(cm)','Petal_length(cm)','Petal_width(cm)']]
y = df['class']

# %%
#Create an instance of the decision tree classifier
dec_tree = DecisionTreeClassifier(criterion='gini',min_samples_split=2)

#Fit the model with the training data X_train and y_train
dec_tree.fit(x, y)
tree.plot_tree(dec_tree)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %% [markdown]
# #### VISUALISATION

# %%
data = tree.export_graphviz(dec_tree, out_file= None, filled= True)
graph = graphviz.Source(data)
graph
